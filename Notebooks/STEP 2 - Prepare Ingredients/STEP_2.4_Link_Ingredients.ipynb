# %%
import pandas as pd
from tqdm import notebook
notebook.tqdm.pandas()

# %%
IF_DF = pd.read_csv('/content/drive/My Drive/Data Science Projects/RecipeApp/data/myData/INGR_FREQ_WITH_FDC.csv', index_col=0)

# %%
ingr_df = pd.read_csv('/content/drive/My Drive/Data Science Projects/RecipeApp/data/myData/INGREDIENTS_FINAL.csv', index_col=0)

# %%
ingr_df = ingr_df.merge(IF_DF, on='name', how='left')

# %%
ingr_df.to_csv('/content/drive/My Drive/Data Science Projects/RecipeApp/data/myData/INGR_FINAL_COMPL_MERGE.csv')
