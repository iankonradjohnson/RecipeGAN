# %%
import pandas as pd

# %%
B_DF = pd.read_csv('/content/drive/My Drive/Data Science Projects/RecipeApp/data/myData/BRANDED_INGR_MASS.csv', index_col=[0]).rename(columns={'serving_size':'grams'})
B_DF = B_DF[['name', 'quantity', 'unit', 'recipe_index','fdc_id', 'sub_qty','sub_unit', 'grams']]
B_DF
# Out:
#                                     name  quantity  ... sub_unit  grams
# 0                              oat flour      0.50  ...      NaN   60.0
# 1                              oat flour      2.00  ...      NaN  240.0
# 2                              oat flour      2.00  ...      NaN  240.0
# 3                              oat flour      0.75  ...      NaN   90.0
# 4                              oat flour      1.00  ...      NaN  120.0
# ...                                  ...       ...  ...      ...    ...
# 105805                   garlic sea salt      0.25  ...     such    2.0
# 105806               mini dogbone treats      8.00  ...      NaN  120.0
# 105808              chocolate milkshakes      2.00  ...      NaN  510.0
# 105809              rocky road ice cream      4.00  ...      NaN  260.0
# 105811  frosted s'mores toaster pastries      2.00  ...     such  208.0
#
# [102093 rows x 8 columns]

# %%
SF_DF = pd.read_csv('/content/drive/My Drive/Data Science Projects/RecipeApp/data/myData/SURVEY_MASS.csv', index_col=[0])
SF_DF.head()
# Out:
#    modifier_x         name  ...  household_sub_unit  household_sub_qty
# 7     divided  white sugar  ...                 NaN                NaN
# 8     divided  white sugar  ...                 NaN                NaN
# 9     divided  white sugar  ...                 NaN                NaN
# 10    divided  white sugar  ...                 NaN                NaN
# 11    divided  white sugar  ...                 NaN                NaN
#
# [5 rows x 18 columns]

# %%
SL_DF = pd.read_csv('/content/drive/My Drive/Data Science Projects/RecipeApp/data/myData/SR_LEGACY_INGR_MASS.csv', index_col=[0])
SL_DF.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-70ff3774efe1> in <module>()
# ----> 1 SL_DF = pd.read_csv('/content/drive/My Drive/Data Science Projects/RecipeApp/data/myData/SR_LEGACY_INGR_MASS.csv', index_col=[0])
#       2 SL_DF.head()
#
# ...

# %%
FF_DF = pd.read_csv('/content/drive/My Drive/Data Science Projects/RecipeApp/data/myData/FOUNDATION_INGR_MASS.csv', index_col=[0])
FF_DF.head()
# Out:
#                                      name  quantity  ... sub_unit       grams
# 0                extra-virgin coconut oil       3.0  ...      NaN   40.234787
# 1                       2% cottage cheese       2.0  ...      NaN   27.500000
# 2            prepared Dijon-style mustard       0.5  ...      NaN    3.000000
# 4                slices thinly sliced ham       8.0  ...      NaN  129.600000
# 5  canned diced tomatoes and green chiles       2.0  ...      NaN   30.625000
#
# [5 rows x 8 columns]

# %%
F_DF = pd.read_csv('/content/drive/My Drive/Data Science Projects/RecipeApp/data/FoodData_Central/food.csv')
I_DF = pd.read_csv('/content/drive/My Drive/Data Science Projects/RecipeApp/data/myData/INGREDIENTS_1.csv', index_col=[0])
#

# %%
I_F_DF = I_DF.merge(F_DF, on='fdc_id', how='left')
SS_DF = I_F_DF[I_F_DF.data_type == 'sub_sample_food']

# %%
SS_DF['grams'] = ''
SS_DF = SS_DF[['name', 'quantity', 'unit', 'recipe_index','fdc_id', 'sub_qty','sub_unit', 'grams']]
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
INGR_MASS_DF = B_DF.append(SF_DF).append(SL_DF).append(FF_DF).append(SS_DF)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-c30a6a561539> in <module>()
# ----> 1 INGR_MASS_DF = B_DF.append(SF_DF).append(SL_DF).append(FF_DF).append(SS_DF)
#
# NameError: name 'SL_DF' is not defined
